# %%
a=100
print("original a ")
a+=3
print a
# Out:
# original a
# 103

# %%
print a
# Out:
# 103

# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction
import matplotlib.pyplot as plt
[Fs, x] = audioBasicIO.readAudioFile("../data/doremi.wav");
F = audioFeatureExtraction.stFeatureExtraction(x, Fs, 0.050*Fs, 0.025*Fs);
F
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           6.75844806e-02,   7.25907384e-02,   7.13391740e-02],
#        [  5.02108526e-11,   5.02108526e-11,   5.02108526e-11, ...,
#           1.43117750e-05,   8.41290936e-06,   5.60482739e-06],
#        [  2.91656459e+00,   2.91656459e+00,   2.91656459e+00, ...,
#           3.19227917e+00,   3.16847566e+00,   3.22278074e+00],
#        ...,
#        [  1.66666667e-01,   1.66666667e-01,   1.66666667e-01, ...,
#           1.14264601e-03,   2.44103796e-03,   6.46500081e-03],
#        [  2.01173973e-35,   2.01173973e-35,   2.01173973e-35, ...,
#           1.69281136e-03,   6.53195059e-04,   5.37891486e-04],
#        [  4.60642332e-02,   4.60642332e-02,   4.60642332e-02, ...,
#           3.19496814e-02,   2.63836535e-02,   2.32505141e-02]])

# %%
plt.subplot(2,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel('ZCR');
plt.subplot(2,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel('Energy');
plt.show()
# plt.close(1)
# plt.close(2)

# %%
b=200
print(b)

# %%
print "aaaa"

# %%
aa="a12345"
aa
# Out:
# 'a12345'

# %%
bb=" bb567 -- "
bb
# Out:
# ' bb567 -- '

# %%
cc=aa+bb
cc
# Out:
# 'a12345 bb567 -- '

# %%
plt.text('11')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e96d06635b7c> in <module>()
# ----> 1 plt.text('11')
#
# TypeError: text() takes at least 3 arguments (1 given)

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
plt.close(1)
