# %%
import pyAudioAnalysis
# from pyAudioAnalysis import audioSegmentation as aS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-1131983b0cfc> in <module>()
# ----> 1 import pyAudioAnalysis
#       2 # from pyAudioAnalysis import audioSegmentation as aS
#
# ModuleNotFoundError: No module named 'pyAudioAnalysis'

# %%
from pyAudioAnalysis import audioSegmentation as aS
[flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/scottish.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
# [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/20170621_16sec.wav", "data/svmSM", "svm", True, 'data/scottish.segments')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-38f1f169a3c4> in <module>()
# ----> 1 from pyAudioAnalysis import audioSegmentation as aS
#       2 [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/scottish.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
#       3 # [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/20170621_16sec.wav", "data/svmSM", "svm", True, 'data/scottish.segments')
#
# ModuleNotFoundError: No module named 'pyAudioAnalysis'

# %%
from pyAudioAnalysis import audioSegmentation as aS
# [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/scottish.wav", "data/svmSM", "svm", True, 'data/scottish.segments')
[flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/20170621_16sec.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9d7071418469> in <module>()
# ----> 1 from pyAudioAnalysis import audioSegmentation as aS
#       2 # [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/scottish.wav", "data/svmSM", "svm", True, 'data/scottish.segments')
#       3 [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/20170621_16sec.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
#
# ModuleNotFoundError: No module named 'pyAudioAnalysis'

# %%
from pyAudioAnalysis import audioSegmentation as aS
[flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/speech_music_sample.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
# [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/20170621_16sec.wav", "data/svmSM", "svm", True, 'data/scottish.segments')

# %%
from pyAudioAnalysis import audioSegmentation as aS
[flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/speech_music_sample.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')

# scottish.segments : 
# 0.01,4.30,music
# 4.30,23.73,speech
# 23.73,216.45,music
# 216.45,234.43,speech
# 234.43,247.32,music

# %%
from pyAudioAnalysis import audioSegmentation as aS
[flagsInd, classesAll, acc, CM] = aS.mtFileClassification("../data/speech_music_sample.wav", "../data/svmSM", "svm", True, '../data/scottish.segments')
# [flagsInd, classesAll, acc, CM] = aS.mtFileClassification("data/20170621_16sec.wav", "data/svmSM", "svm", True, 'data/scottish.segments')

# %%
from pyAudioAnalysis import audioBasicIO as aIO
from pyAudioAnalysis import audioSegmentation as aS
[Fs, x] = aIO.readAudioFile("../data/20170621_16sec.wav")
segments = aS.silenceRemoval(x, Fs, 0.020, 0.020, smoothWindow = 1.0, Weight = 0.3, plot = True)

# %%
from pyAudioAnalysis import audioBasicIO as aIO
from pyAudioAnalysis import audioSegmentation as aS
[Fs, x] = aIO.readAudioFile("/Users/wang/mine/maxnerva/proj/pyAudioAnalysis/20170701/[20170305]-[LHWR]-[107Mini]-[Terry]-[original].wav")
segments = aS.silenceRemoval(x, Fs, 0.020, 0.020, smoothWindow = 1.0, Weight = 0.3, plot = True)

# %%
[Fs, x] = aIO.readAudioFile("/Users/wang/mine/maxnerva/proj/pyAudioAnalysis/20170701/[20170305]-[LHWR]-[107Mini]-[Terry]-[original].wav")
segments = aS.silenceRemoval(x, Fs, 0.020, 0.020, smoothWindow = 0.5, Weight = 0.3, plot = True)
