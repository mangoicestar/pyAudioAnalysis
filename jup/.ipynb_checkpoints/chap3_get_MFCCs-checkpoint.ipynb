# %% [markdown]
# ##### doremi.wav

# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction
import matplotlib.pyplot as plt
[Fs, x] = audioBasicIO.readAudioFile("../data/doremi.wav");
F = audioFeatureExtraction.stFeatureExtraction(x, Fs, 0.050*Fs, 0.025*Fs);
plt.subplot(2,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel('ZCR'); 
plt.subplot(2,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel('Energy'); plt.show()

# %% [markdown]
# ##### 16秒的那個音檔 ：

# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction
import matplotlib.pyplot as plt
# print "1111"
[Fs, x] = audioBasicIO.readAudioFile("../data/20170621_16sec.wav");

F = audioFeatureExtraction.stFeatureExtraction(x, float(Fs), float(0.1*Fs), float(0.1*Fs));

# %%
plt.subplot(3,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel('ZCR'); 
plt.subplot(3,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel('Energy');
plt.subplot(3,1,3); plt.plot(F[2,:]); plt.xlabel('Frame no'); plt.ylabel('Entropy of Energy'); 

plt.show()

# %%
plt.subplot(4,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel('ZCR'); 
plt.subplot(4,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel('Energy');
plt.subplot(4,1,3); plt.plot(F[2,:]); plt.xlabel('Frame no'); plt.ylabel('E of E'); 
plt.subplot(4,1,4); plt.plot(F[3,:]); plt.xlabel('Frame no'); plt.ylabel('spec cen'); 
plt.show()

# %% [markdown]
# ### 同一個音檔，取得第 9~21 的 feature
# - F[ ] 從 0 開始

# %%
plt.subplot(2,1,1); plt.plot(F[8,:]); plt.xlabel('Frame no'); plt.ylabel('9');     plt.show() 
plt.subplot(2,1,1); plt.plot(F[9,:]); plt.xlabel('Frame no'); plt.ylabel('10');   plt.show() 
plt.subplot(2,1,1); plt.plot(F[10,:]); plt.xlabel('Frame no'); plt.ylabel('11'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[11,:]); plt.xlabel('Frame no'); plt.ylabel('12'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[12,:]); plt.xlabel('Frame no'); plt.ylabel('13'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[13,:]); plt.xlabel('Frame no'); plt.ylabel('14'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[14,:]); plt.xlabel('Frame no'); plt.ylabel('15'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[15,:]); plt.xlabel('Frame no'); plt.ylabel('16'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[16,:]); plt.xlabel('Frame no'); plt.ylabel('17'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[17:]); plt.xlabel('Frame no'); plt.ylabel('18');  plt.show() 
plt.subplot(2,1,1); plt.plot(F[18,:]); plt.xlabel('Frame no'); plt.ylabel('19'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[19,:]); plt.xlabel('Frame no'); plt.ylabel('20'); plt.show() 
plt.subplot(2,1,1); plt.plot(F[20,:]); plt.xlabel('Frame no'); plt.ylabel('21'); plt.show()

# %%
[Fs1, x1] = audioBasicIO.readAudioFile("/Users/wang/mine/maxnerva/proj/pyAudioAnalysis/20170701/[20170305]-[LHWR]-[107Mini]-[Terry]-[original].wav");
F1 = audioFeatureExtraction.stFeatureExtraction(x1, float(Fs1), float(0.1*Fs1), float(0.1*Fs1));
plt.subplot(2,1,2); plt.plot(F1[1,:]); plt.xlabel('Frame no'); plt.ylabel('Energy');plt.show();
plt.subplot(2,1,2); plt.plot(F1[2,:]); plt.xlabel('Frame no'); plt.ylabel('EoE');plt.show();
